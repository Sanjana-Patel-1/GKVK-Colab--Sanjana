# %%
crop="rice"
soil_type="black soil"
print(len(crop))
print(crop)
print(soil_type)
# Out:
# 4
# rice
# black soil

# %%
my_name="sindhu_madiwal"
print(my_name[0])
print(my_name[-1])
print(my_name[:4])
print(my_name[5:])
# Out:
# s
# l
# sind
# u_madiwal

# %%
print("manimala".upper())
print("prarthana".lower())
print("dhruvanth".title())
print("sindhu".capitalize())
# Out:
# MANIMALA
# prarthana
# Dhruvanth
# Sindhu

# %%
customer="rukmini_ram"
print(customer.strip())
print("***manimala".lstrip("*"))
print("hemanth###".rstrip("#"))
print("***umesh_krishna".lstrip("*"))
# Out:
# rukmini_ram
# manimala
# hemanth
# umesh_krishna

# %%
text="good things take time"
print(text.find("things"))
print(text.count("things"))
print("live" in text)
# Out:
# 5
# 1
# False

# %%
print("sindhumadiwal".isalpha())
print("15082003".isdigit())
print("rcrka36".isalnum())
print(" ".isspace())
# Out:
# True
# True
# True
# True

# %%
codes= [
    "RCR_sindhu_2003",
    "CKM_umesh_1996",
    "RCR_sridevi_2003",
    "CKM_hemanth_1994",
    "RCR_ramya_2002"
    ]

clean_codes= []
for code in codes:
  if code.startswith("RCR_"):
    clean_codes.append(code[4:])

    print(clean_codes)
# Out:
# ['sindhu_2003']
# ['sindhu_2003', 'sridevi_2003']
# ['sindhu_2003', 'sridevi_2003', 'ramya_2002']

# %%
for native_code in codes:
  if native_code.startswith("CKM_"):
    native_code, name, year= native_code.split("_")
    print(name,native_code)
# Out:
# umesh CKM
# hemanth CKM

# %%
raw_record="rice,1200,black soil**"
clean_record=raw_record.strip()
clean_record1= clean_record.rstrip("**")
crop,yield_kg,soil=clean_record1.split(",")
crop=crop.title()

print(f"yield:{yield_kg}")
print(f"crop:{crop}")
print(f"soil:{soil}")
# Out:
# yield:1200
# crop:Rice
# soil:black soil
