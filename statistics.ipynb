# %%
import numpy as np
#rainfall data(mm) over 12 months
rainfall=np.array([45,52,68,120,180,220,195])
#corresponding crop yield(tons/hectare)
yields=np.array([2.1,2.3,2.8,4.2,5.8,6.5,5.9])

print('====RAINFALL STATISTICS===')
print(f'Mean:{np.mean(rainfall):.2f}mm')
print(f'meadian:{np.median(rainfall):.2f}mm')
print(f'Std Dev:{np.std(rainfall):.2f}mm')
print(f'Variance:{np.var(rainfall):.2f}mm')
print(f'Min:{np.min(rainfall)}mm(month{np.argmin(rainfall)+1})')
print(f'Max:{np.max(rainfall)}mm (Month{np.argmax(rainfall)+1})')
print(f'Range:{np.ptp(rainfall):.2f}mm')
print(f'cumulative:{np.cumsum(rainfall)[1]:.2f}mm')

print('\n===Yield Statistics===')
print(f'Mean:{np.mean(yields):.2f}tons/ha')
print(f'Median:{np.median(yields):.2f}tons/ha')
print(f'Std Dev:{np.std(yields):.2f}tons/ha')

print('\n\n\n===PERCENTILES====')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip(percentiles,rainfall_percentiles):
  print(f'{p}th percentile rainfall:{val:.2f}mm')

print('\n\n\n===CORRELATION ANALYSIS===')
correlation_matrix=np.corrcoef(rainfall,yields)
correlation=correlation_matrix[0,1]
print(f'Rainfall yield correlation:{correlation:.4f}')
print('Interpretation:strong positive correlation' if correlation>0.7 else 'Moderate correlation'if correlation>0.4 else 'weak correlation')

print('\n\n===CUMULATIVE RAINFALL===')
cumulative=np.cumsum(rainfall)
print('rainfall\tcumulative')
for (rain,cum) in zip(rainfall,cumulative):
  print(f'{rain}\t{cum}')
# Out:
# ====RAINFALL STATISTICS===
# Mean:125.71mm
# meadian:120.00mm
# Std Dev:67.56mm
# Variance:4564.20mm
# Min:45mm(month1)
# Max:220mm (Month6)
# Range:175.00mm
# cumulative:97.00mm
#
# ===Yield Statistics===
# Mean:4.23tons/ha
# Median:4.20tons/ha
# Std Dev:1.72tons/ha
#
#
#
# ===PERCENTILES====
# 25th percentile rainfall:60.00mm
# 50th percentile rainfall:120.00mm
# 75th percentile rainfall:187.50mm
# 90th percentile rainfall:205.00mm
#
#
#
# ===CORRELATION ANALYSIS===
# Rainfall yield correlation:0.9980
# Interpretation:strong positive correlation
#
#
# ===CUMULATIVE RAINFALL===
# rainfall	cumulative
# 45	45
# 52	97
# 68	165
# 120	285
# 180	465
# 220	685
# 195	880

# %%
import numpy as np
#rainfall data(mm) over 12 months
rainfall=np.array([45,52,68,120,180,220,195])
#corresponding crop yield(tons/hectare)
yields=np.array([2.1,2.3,2.8,4.2,5.8,6.5,5.9])
 print('===RAINFALL STATISTICS===')
 print(f'mean:{np.mean(rainfall):2f}mm')
 print(f'median:{np.median(rainfall):2f}mm')
 print(f'std dev:{np.std(rainfall):2f}mm')
 print(f'variance:{np.var(rainfall):2f}mm')
 print(f'min:{np.min(rainfall)}mm(month{np.argmin(rainfall)+1})')
 print(f'max:{np.max(rainfall)}mm(month{np.argmax(rainfall)+1})')
 print(f'range:{np.ptp(rainfall)}mm')
 print(f'cumulative:{np.cumsum(rainfall)[1]:.2f}mm')

print('\n====Yield Statistics====')
print(f'Mean:{np.mean(yields):.2f}tons/ha')
print(f'Median:{np.median(yields):.2f}tons/ha')
print(f'Std Dev:{np.std(yields):.2f}tons/ha')
print(f'variance:{np.var(yields):.2f}tons/ha')
