# %%
import numpy as np
a=np.array([1,2])
b=np.array([3,4])
print(np.dot(a,b))

# %%
import numpy as np
np.eye(2)

# %%
import numpy as np
np.arange(1,10,2)

# %%
a=np.array([[1,2],[3,4],[5,6]])
print(a.flatten())

# %%
import pandas as pd
df=pd.DataFrame({
    "A":[10,20,30]
})
print(df.iloc[1])
