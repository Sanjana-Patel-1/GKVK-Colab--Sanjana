# %%
def crop_yield():
  get_yield=[]
  n=int(input("enter the number of fields:"))
  for i in range(n):
    value=int(input("enter the  yield in kg:"))
    get_yield.append(value)
  return get_yield
print(crop_yield())

#def record(get_yields):
  #print("recorded crop yield:",get_yields))
#record(get_yields)



def average_yield(get_yield):
   total=sum(get_yield)/len(get_yield)
   return total
print(average_yield(get_yield))

#def threshold_crops(yields,threshold):
 # high=[]
 # for value in yields:
   # if value>=threshold:
    #  high.append(value)
 # return high
#print(threshold_crops(yields,12))
# Out:
# enter the number of fields:2
# enter the  yield in kg:10
# enter the  yield in kg:20
# [10, 20]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4282968541.py in <cell line: 0>()
#      17    total=sum(get_yield)/len(get_yield)
#      18    return total
# ---> 19 print(average_yield(get_yield))
#      20
#      21 #def threshold_crops(yields,threshold):
#
# NameError: name 'get_yield' is not defined
