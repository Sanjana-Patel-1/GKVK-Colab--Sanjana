# %%
#display result
if avg_rainfall>=100:
  print("sufficient rainfall")
else:
  print("insufficient rainfall")#accept rainfall values for 5 days
rainfall=[]
for i in range(5):
    rain=float(input(f"enter rainfall for day{i+1}:"))
    rainfall.append(rain)

#calculate average rainfall
avg_rainfall=sum(rainfall)/5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_26303/3703646461.py in <cell line: 0>()
#       1 #display result
# ----> 2 if avg_rainfall>=100:
#       3   print("sufficient rainfall")
#       4 else:
#       5   print("insufficient rainfall")#accept rainfall values for 5 days
#
# NameError: name 'avg_rainfall' is not defined

# %%
#repeatedly accept maturity percentage
while True:
      maturity=float(input("enter crop maturity percentage:"))
      if maturity>=100:
        print("crop ready for harvest")
        break
# Out:
# enter crop maturity percentage:99
# enter crop maturity percentage:76
# enter crop maturity percentage:101
# crop ready for harvest
