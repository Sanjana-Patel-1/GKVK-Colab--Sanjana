# %%
count=1
while Ture:
  print(count)
  if count==5:
     break
     count+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3231255746.py in <cell line: 0>()
#       1 count=1
# ----> 2 while Ture:
#       3   print(count)
#       4   if count==5:
#       5      break
#
# NameError: name 'Ture' is not defined
