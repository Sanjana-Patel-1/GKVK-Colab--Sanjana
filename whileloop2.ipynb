# %%
water_level=20 #in percentage
while water_level<50:
    print("irrigation ON_water level:",water_level,"%")
    water_level+=5
print("sufficient water,irrigation OFF")
# Out:
# irrigation ON_water level: 20 %
# irrigation ON_water level: 25 %
# irrigation ON_water level: 30 %
# irrigation ON_water level: 35 %
# irrigation ON_water level: 40 %
# irrigation ON_water level: 45 %
# sufficient water,irrigation OFF
